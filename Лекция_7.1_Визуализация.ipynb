# %% [markdown]
# # Визуализация данных в python

# %% [markdown]
# Для того, чтобы поулчить данные, визуализровать их - нужны библиотеки.
#
# Их можно подклучить с помощью специальной команды `import`. Например:

# %%
import matplotlib.pyplot as plt  # библиотека для рисования 
import math

# import pandas as pd  # библиотека для работы с данными

# %% [markdown]
# ## Простой график

# %% [markdown]
# Начнём с самых простых графиков и тех функций языка `Python`, которые вы знаете.
#
# #### Генерируем набор данных

# %%
data = range(10)
print(data)
# Out:
# range(0, 10)

# %% [markdown]
# #### Строим график с помощью команды plot

# %%
plt.plot(data)

# %% [markdown]
# ## Настройка внешнего вида графика

# %% [markdown]
# #### Тип и цвет линии
#
# Можно посомтреть через справку ,выполнив следующую команду

# %%
# ?plt.plot

# %%
plt.plot(data, color = [1, 0.5, 0])

# %%
plt.plot(data, 'o')

# %%
plt.plot(data, '--')

# %%
plt.plot(data, '-.')

# %%
plt.plot(data, 'y*')

# %% [markdown]
# #### Задаем размер графика

# %%
plt.figure(figsize=(10, 3))
plt.plot(data)

# %% [markdown]
# #### Добавляем сетку

# %%
plt.figure(figsize=(10, 6))
plt.grid()
plt.plot(data)

# %% [markdown]
# #### Добавляем название графика

# %%
plt.title('Plot name')
plt.plot(data)

# %%
#не будет работать!? важна кодировка
plt.title('Русскоязычное название')
plt.plot(data)

# %%
# учитвание кодировки символом 'u'
plt.title(u'Русскоязычное название', family="freemono")
plt.plot(data)

# %% [markdown]
# #### Подписи к осям

# %%
plt.title(u'Название', family='verdana')
plt.grid()
plt.xlabel(u'ось x', family='verdana')
plt.ylabel(u'ось y', family='verdana')
plt.plot(data)

# %% [markdown]
# #### Подписи на графике

# %%
plt.grid()
plt.title(u'Навзание', family='verdana')
plt.xlabel(u'ось x', family='verdana')
plt.ylabel(u'ось y', family='verdana')
plt.text(4.5, 7, u'очень важный комментарий', family="verdana")
plt.plot(data)

# %%
# ?plt.arrow

# %%
plt.grid()
plt.text(4.5, 7, u'очень важный комментарий', family="verdana")
plt.arrow(6,1, -2, 2, width = 0.3)
plt.plot(data)

# %% [markdown]
# ## Много графиков на одной плоскости

# %% [markdown]
# #### Сгенирируем данные

# %%
linear = range(10)
nonlinear = [x**2 for x in range(10)]
print(linear)
print(nonlinear)
# Out:
# range(0, 10)
# [0, 1, 4, 9, 16, 25, 36, 49, 64, 81]

# %% [markdown]
# #### Построим график

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')

# %%
plt.grid()
plt.plot(linear)
plt.plot(nonlinear)

# %% [markdown]
# #### Легенда

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')
plt.legend(['linear', 'nonlinear'])

# %%
# ?plt.legend

# %%
plt.grid()
plt.plot(linear, label='linear')
plt.plot(nonlinear, label='nonlinear')
plt.plot([1,2,4,5,9,2])
plt.legend()

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')
plt.legend(['linear', 'nonlinear'], loc='best')

# %% [markdown]
# ## Много графиков на одном изображении

# %%
plt.figure(figsize=(10,4))

plt.subplot(122)
plt.grid()
plt.plot(linear, 'b-')

plt.subplot(121)
plt.grid()
plt.plot(nonlinear, 'g-')

# %%
plt.figure(figsize=(5,5))

plt.subplot(2,2,1)
plt.grid()
plt.plot(linear, 'b-')

plt.subplot(2,2,2)
plt.grid()
plt.plot(nonlinear, 'g-')

plt.subplot(2,2,3)
plt.grid()
plt.plot(linear, 'b-')

plt.subplot(2,2,4)
plt.grid()
plt.plot(nonlinear, 'g-')

# %% [markdown]
# ## Как сохранить график

# %%
plt.grid()
plt.plot(linear, 'b-')
plt.plot(nonlinear, 'g-')
plt.legend(['linear', 'nonlinear'], loc=2)
plt.savefig('./saved_plot.png')

# %% [markdown]
# Мы научились:
#    * Строить графики в matplotlib - команда plot();
#    * Настраивать внешний вид графика: сетка, подписи, несколькго графиков;
#    * Созранять полученне графики в виде изображения для дальнейшего использования.

# %% [markdown]
# ## Математические формулы

# %%
import numpy as np

# %%
x = np.arange(-10, 10.01, 0.01)
print(x)
# Out:
# [-10.    -9.99  -9.98 ...   9.98   9.99  10.  ]

# %%
plt.plot(x, x**2)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(x, np.sin(x), x, np.cos(x), x, -x)
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
plt.plot(np.sin(x), np.cos(x+0.1))
plt.show()

# %% [markdown]
# Или используя legend(), где можно указать место расположения подписей к кривым на графике в параметре loc. Подписи могут быть явно переданы legend((line1, line2, line3), ('label1', 'label2', 'label3')) или могут быть переданы в аргумет label, как в примере ниже. Чтобы сохранить график нужно воспользоваться savefig(figure_name), где figure_name явлется строкой назания файла с указанием расширения. Для текстовых полей можно изменять шрифт (fontsize), для большей читаемости графика, а его размер указывается с помощью figure(figsize=(10, 5)).

# %%
x = np.arange(-10, 10.01, 0.01)

plt.figure(figsize=(10, 5))

plt.plot(x, np.sin(x), label=r'$f_1(x)=\sin(x)$')
plt.plot(x, np.cos(x), label=r'$f_2(x)=\cos(x)$')
plt.plot(x, -x, label=r'$f_3(x)=-x$')

plt.xlabel(r'$x$', fontsize=14)
plt.ylabel(r'$f(x)$', fontsize=14)
plt.grid(True)
plt.legend(loc='best', fontsize=12)
plt.savefig('figure_with_legend.png')
plt.show()

# %%
x = np.arange(-10, 10.01, 0.01)
t = np.arange(-10, 11, 1)

plt.figure(figsize=(10,10))

#subplot 1
sp = plt.subplot(221)
plt.plot(x, np.sin(x))
plt.title(r'$\sin(x)$')
plt.grid(True)

#subplot 2
sp = plt.subplot(222)
plt.plot(x, np.cos(x), 'g')
plt.axis('equal')
plt.grid(True)
plt.title(r'$\cos(x)$')

#subplot 3
sp = plt.subplot(223)
plt.plot(x, x**2, t, t**2, 'ro')
plt.title(r'$x^2$')

#subplot 4
sp = plt.subplot(224)
plt.plot(x, x)
sp.spines['left'].set_position('center')
sp.spines['bottom'].set_position('center')
plt.title(r'$x$')

plt.show()

# %% [markdown]
# ###  Гистограмма

# %%
data = [33, 25, 20, 12, 25, 9]

plt.figure(num=1, figsize=(6, 6))
plt.axes(aspect=1)
plt.title('Численность студентов', size=14)

plt.pie(data, labels=('Group 1', 'Group 2', 'Group 3', 'Group 4', 'Group 5', 'Group 6'))
plt.show()

# %%
objects = ('A', 'B', 'C', 'D', 'E', 'F')
y_pos = np.arange(len(objects))
performance = [10,8,6,4,2,1]

plt.bar(y_pos, performance, align='center', alpha=0.5)
plt.xticks(y_pos, objects)

plt.ylabel('Value')
plt.title('Bar title')

plt.show()

# %%
print(objects)
print(y_pos)
print(performance)
# Out:
# ('A', 'B', 'C', 'D', 'E', 'F')
# [0 1 2 3 4 5]
# [10, 8, 6, 4, 2, 1]

# %% [markdown]
# ### Трёхмерные графики

# %%
import pylab from mpl_toolkits.mplot3d import Axes3D from matplotlib import cm

# %%
def makeData():
    x = np.arange(-10, 10, 0.1)
    y = np.arange(-10, 10, 0.1)
    xgrid, ygrid = np.meshgrid(x, y)
    zgrid = np.sin(xgrid)*np.sin(ygrid)/(xgrid*ygrid)
    return xgrid, ygrid, zgrid

x, y, z = makeData()

fig = pylab.figure()
# axes = Axes3D(fig)
# plt.plot_surface(x, y, z, rstride=4, cstride=4, cmap=cm.jet)
pylab.show()

# %%
x = [1, 2, 3, 4, 5]
y = [0.99, 0.49, 0.35, 0.253, 0.18]
plt.errorbar(x, y, xerr=0.05, yerr=0.1)
plt.grid()
plt.show()

# %%
t = 
f = sin(t)

plt.grid()
plt.plot(t,f)

# %% [markdown]
# # Картинки

# %%
im = plt.imread('./pics/hand_hello.jpg')
plt.imshow(im)

# %%
im = plt.imread('./pics/ven.png')

plt.figure(figsize=(7,7))
plt.imshow(im)

# %% [markdown]
# # Домашнее задание

# %%
t = np.arange(-10, 10, 0.1)
# print(t)
f = -(5+4*t)**3+8*t
# print(f)

plt.figure()
plt.plot(t,f)

plt.grid()
plt.title('График функции')
plt.show()

# %%
type(t)
# Out:
# numpy.ndarray

# %%
np.sin([0.5, 3, 6, 71])
# Out:
# array([ 0.47942554,  0.14112001, -0.2794155 ,  0.95105465])

# %%
f1 = -np.sin(5+4*t)+np.cos(8*t)


plt.figure()
plt.plot(f, f1)

plt.grid()
plt.title('График функции')
plt.show()

# %% [markdown]
# 1. Дана функция `y=f(x)`. Построить график функции
#
# |||
# |:|:-|
# |A | y = 2x - 10, если x > 0 <br />   y = 0, если x = 0 <br />     y = 2 * \|x\| - 1, если x < 0	 <br />
# B| y = $2x^2$ + 10, если x > 5 <br /> y = 0, если x = 0 <br /> y = 2 * \|x+6\| - x2, если x < 5
# C | y = 5x - 10, если x > 3 <br />      y = 1, если x = 3 <br />     y = 2 * \|x\| - 5, если x < 3
# D | y = $(2+x)^2$ + 7, если x > -8 <br />     y = 5, если x = -8 <br />      y = \|2 * x-1\| - 1, если x < -8
# E | y = 1,5x + 5, если x > 0 <br />     y = -2, если x = 0 <br />    y = 2 * \|x+4\| - 6, если x < 0
# F | y = 2x - 10, если x > 3 <br />     y = 10, если x = 3 <br />    y = (2 * x+1)2 - 1, если x < 3
# G | y = 3x - 7, если x > 1 <br />    y = 3, если x = 1 <br />    y = 3 * \|x+2\| - 7, если x < 1
# H | y = $2x^2$ - 3, если x > 7 <br />     y = 0, если x = 7 <br />     y = 2 * \|x\| + 3, если x < 7
# I | y = 2x - 15, если x > 2 <br />     y = 5, если x = 2 <br />     y = 3 * \|x-1\| - 8, если x < 2
# J | y = 3x - 5, если x > 5 <br />     y = 10, если x = 5 <br />     y = 2 * \|x-2\| + 5, если x < 5
# K | y = -x, если x <= 0 <br /> y = $x^2$, если 0 <= x < 2 <br /> y = 4, если x >= 2
# L | y = 2 sin(x), если x > 0 <br /> y = 6-x, если 0 <= x < 10 <br /> y = -4, если x >= 10
#
# 2. Дана функция `y=f(x)`. Построить график функции
#     - $  (a+4x)(a−3x)+a^2$ при a=2
#     - $ |x| + x^5. $
#     - $ (x+1)^2+3(x+1) $
#     - $ (|x-5|-sinx)/3 +\sqrt{x^2+2014}  cos(2x) – 3 $
#     - $ e^{x-2}+|sin⁡(x) |-x^4  cos⁡(1/x)$
#     - $ \sqrt{(x2+b)}-[b^2 sin(x+a)]/x$ при a=0.1, b=0.2
#
# 3. Дана функция `y=f(x)`. Построить график функции (шаг и диапазон задаёт пользователь):
#
#     - $ y = -0.23x^2 + x $
#     - $ y = -0.1x^2 + 2x+1 $
#     - $ y = -2x^2 + 3x-1$
#     - $ y = (-3+x)^2 + 2x+5$
#     - $ y = (2+x)^2 + 3x$
#     - $ y = \sqrt{-(1+3x)/2}+ 3x$
#     - $ y = -(2+9x)^2 + 6x$
#     - $ y = -(5+4x)^3 + 8x$
#     - $ y = -x(3+2x)^2 + 3x+sin(2x)$
#     - $ y = (5+4x)^2 + 8x+cos(21x+10)$
#     - $ y = \sqrt{5+4x}  + 13x+cos(12x+91)$
#     - $ y = \sqrt{5x+4x^3}  + 4x+3/sin(9x+71)$
#     - $ y = \sqrt{2+4x^2}  + 6x+sin(8x+11)$
#     - $ y = \sqrt{2+3x}  + 72x+tg(4x+31)$
#     - $ y = \sqrt{15+4/x}  + 13x+sin(3x+13)$
#     - $ y = \sqrt{5+3/x}  + 11x+ctg(2x+15)$
